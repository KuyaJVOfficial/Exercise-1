# %%
first_variable = "ice_cream_rating"
second_variable = "sleeping_rating"

place1 = input("ice_cream_rating")
print(place1, "Thank you")
place2 = input(second_variable)
print(place2, "Thank you")

third_variable = "first_name"
fourth_variable = "last_name"

place3 = input(third_variable)
print(place3, "is a good name!")
place4 = input(fourth_variable)
print(place4, "is a good surname!")

print("My name:", place3, place4)


variable = (int(place1)+int(place2))/2
print("happiness_rating: ", variable)
# Out:
# ice_cream_rating 7
# 7 Thank you
# sleeping_rating 8
# 8 Thank you
# first_name Kuya
# Kuya is a good name!
# last_name JV
# JV is a good surname!
# My name: Kuya JV
# happiness_rating:  7.5

# %%
print("ice_cream_rating", type(first_variable))
print("first_name", type(third_variable))
print("happiness_rating", type(variable))
# Out:
# ice_cream_rating <class 'str'>
# first_name <class 'str'>
# happiness_rating <class 'float'>

# %%
percentage = (variable/20)*100

print("My name is", place3, "and I give eating ice cream a score of", place1 , "out of 10!")
print("I am", place3, place4, "and my sleeping enjoyment rating is", place2, "/ 10!")
print("Based on the factors above, my happiness rating is", variable, "out of 10, or" , percentage , "!")
# Out:
# My name is Kuya and I give eating ice cream a score of 7 out of 10!
# I am Kuya JV and my sleeping enjoyment rating is 8 / 10!
# Based on the factors above, my happiness rating is 7.5 out of 10, or 37.5 !
